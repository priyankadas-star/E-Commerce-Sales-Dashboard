# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/priyanka das/OneDrive/Desktop/E com sales new.csv")
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 1      2  404-0687676-7273146  4/30/2022                       Shipped
# 2      6  408-5748499-6859555  4/30/2022                       Shipped
# 3      7  406-7807733-3785945  4/30/2022  Shipped - Delivered to Buyer
# 4     14  408-1298370-1920302  4/30/2022  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 1     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 2     Amazon      Amazon.in          Expedited    J0095      J0095-SET-L
# 3   Merchant      Amazon.in           Standard  JNE3405     JNE3405-KR-S
# 4   Merchant      Amazon.in           Standard    J0351      J0351-SET-L
#
#   Category  ... Qty currency Amount    ship-city   ship-state  \
# ...

# %%
df.tail(5)
# Out:
#          index             Order ID       Date   Status Fulfilment  \
# 128957  128970  406-6001380-7673107  5/31/2022  Shipped     Amazon
# 128958  128971  402-9551604-7544318  5/31/2022  Shipped     Amazon
# 128959  128972  407-9547469-3152358  5/31/2022  Shipped     Amazon
# 128960  128973  402-6184140-0545956  5/31/2022  Shipped     Amazon
# 128961  128974  408-7436540-8728312  5/31/2022  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128957      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128958      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128959      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128960      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128961      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... Qty currency  Amount  ship-city    ship-state  \
# 128957          kurta  ...   1      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6870
# Qty                       0
# currency               7794
# Amount                 7794
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49143
# B2B                       0
# fulfilled-by          89688
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df=df[df['Status']!='Cancelled']

# %%
df.to_csv('Cleaned_Ecommerce.csv',index=False)

# %%
df=pd.read_csv('Cleaned_Ecommerce.csv')
df.head()
# Out:
#    index             Order ID        Date                        Status  \
# 0      1  171-9198151-1101146  2022-04-30  Shipped - Delivered to Buyer
# 1      2  404-0687676-7273146  2022-04-30                       Shipped
# 2      6  408-5748499-6859555  2022-04-30                       Shipped
# 3      7  406-7807733-3785945  2022-04-30  Shipped - Delivered to Buyer
# 4     14  408-1298370-1920302  2022-04-30  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 1     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 2     Amazon      Amazon.in          Expedited    J0095      J0095-SET-L
# 3   Merchant      Amazon.in           Standard  JNE3405     JNE3405-KR-S
# 4   Merchant      Amazon.in           Standard    J0351      J0351-SET-L
#
#   Category  ... Qty currency Amount    ship-city   ship-state  \
# ...
